# %%
a=100
b=100

print(a is  b)
print(a == b)
# Out:
# True
# True

# %%
print("Rahul" in ["Rahul","Sonia","Priyanka"])
# Out:
# True

# %%
print("Rahul Gandhi" in ["Rahul","Sonia","Priyanka"])
# Out:
# False

# %%
print( 'R'  in 'Rahul')
# Out:
# True

# %%
print(2*3)
# Out:
# 6

# %%
print(2*  "3")
# Out:
# 33

# %%
print(2* "Rahul")
# Out:
# RahulRahul
